# %% [markdown]
# # Machine Learning - 1st Project phase (Evaluation Phase)

# %% [markdown]
# ### 1) Baseball Case Study

# %% [markdown]
# -- Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input Features
#
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
baseball = pd.read_csv("C:/Users/user/Downloads/baseball.csv")
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
baseball.shape
# Out:
# (30, 17)

# %%
#Checking for null values
baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#Checking for Duplicates
baseball.duplicated().sum()
# Out:
# 0

# %% [markdown]
# -- No null values and duplicate values present in the dataset

# %%
#Checking for dataset info
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking the number of unique values of each column
baseball.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# -- Now that we have seen the information about the dataset, we shall move onto the Univariate Analysis and the statistics of the dataset..

# %% [markdown]
# ## Univariate Analysis

# %%
#Checking statistical info for numerical columns
baseball.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %% [markdown]
# -- Take-Aways:
#
# 1) Average Runs Scored during that season is 688 runs...The runs scored during that season ranges from almost 573 to 891 runs
# 2) The Average base hits (i.e the feature 'H' - when the batter safely reaches the first base) during that season is 1403...And the hits ranges from 1324 to 1515..
# 3) The Average two-base hits (i.e 2B) is more than the average three-base hits (i.e 3B) where the former has an average of 275 and the latter has an average of just 31 during that season..
# 4) The max number of home runs(HR) hit is also high with 232...averaging upto 163 in that season..
# 5) The max number of strikeouts (SO) is also high with 1518...averaging upto 1248 in that season..which suggests that the pitchers were really good that season..
# 6) Average number of games this season where the player was the only pitcher for their team is around 3.4 (i.e CG)
# 7) Average number of games this season where a single pitcher pitches a complete game without giving a single run is around 11.3 games (i.e SHO)..which is really good..
# 8) The max number of Errors this season is at 126..averaging almost 94 errors this season..
# 9) The difference between the max value and the third quartile is not huge but we can see a noteable difference and hence there might not be much outliers present in the dataset..
# 10) Total number of features in the dataset is 17..of which
#
#     a)No. of Features which are skewed to the right(positive skewness) - 7
#
#     b)No. of Features which are skewed to the left(negative skewness) - 8
#
#     c)Feature with perfect distribution (i.e mean = median) - 2 (Feature - 'SB','W')

# %%
#Distribution of skewness
for column in baseball.columns:
    plt.figure(column, figsize = (6,6))
    sns.histplot(x = column,data = baseball,kde=True)
    plt.title(column)
    plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# -- Now we shall see how the variables(features) are related to each other and what can we derive from them. Also we shall check how the independent variables are correlated to the dependent feature.

# %%
for column in baseball.columns:
    plt.figure(column, figsize = (6,6))
    baseball.plot.scatter(x = column,y = 'W')
    plt.title(column)
    plt.show()

# %% [markdown]
# Take-Aways:
#
# 1) From the above scatter plots, plotted between the output feature (W) and independent feature..
#
#    a) None of the independent feature has a strong positive correlation with the output feature(W).
#
#    b) Feature like 'RA','ER' and 'ERA' seems to have slightly negative correlation with the output feature(W).
#
#    c) Feature like 'SV' seems to have better positive correlation compared to the other independent features which are scattered without a definite pattern or so.

# %% [markdown]
# ## Multivariate Analysis

# %%
#Plotting the target variable against the independent variables using pairplot,so that the underlying linear relationship becomes more evident..
sns.pairplot(baseball)

# %% [markdown]
# ## Feature Engineering and Feature Selection

# %%
#Now let's detect outliers from the dataset and remove them only if needed..
for column in baseball.columns:
    plt.figure(column, figsize = (6,6))
    sns.boxplot(baseball[column])
    plt.title('Detection of outliers in {} using boxplot'.format(column))
    plt.show()

# %% [markdown]
# -- There are some outliers present in the given dataset..as the number of outliers is very less we will not remove them as it does not affect the data in the prediction process..

# %%
# Now let's check for correlation of variables
baseball_cor = baseball.corr()
baseball_cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# Now let's visualise the above correlation values using heatmap and drop any columns which are least correlated to the target variable
plt.figure(figsize=(12,12))
sns.heatmap(baseball_cor, annot = True)
plt.title("Correlation between the columns")
plt.show()

# %% [markdown]
# -- From the above correlation matrix heatmap,
#
# We see that there is presence of multicollinearity in the dataset..
#
# Multicollinearity - Multicollinearity occurs when there are two or more independent features which have high correlation among themselves..
#
# The Features - 'RA','ER' and 'ERA' are multicollinear and also these feature are very negatively correlated with the target or output variable (W)..
#
# We shall be droping the above mentioned columns and again check for correlation..

# %%
#Dropping columns having multicollinearity
baseball.drop('RA', axis=1, inplace = True)
baseball.drop('ER', axis=1, inplace = True)
baseball.drop('ERA', axis=1, inplace = True)

# %%
#Again checking correlation
baseball_cor = baseball.corr()
baseball_cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(baseball_cor, annot = True)
plt.title("Correlation between the columns")
plt.show()

# %% [markdown]
# -- Now, we see that we have treated the multicollinearity by dropping the columns..
#
# The columns 'R','2B','BB','SHO' and 'SV' have positive correlation with the output variable ('W').

# %%
#Checking for skewness
baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# -- No skewness can be observed from the dataset..

# %% [markdown]
# ## Data Pre-processing

# %%
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# ...

# %%
y = baseball['W']
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x = baseball.drop('W',axis=1)
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 5   891  5509  1480  308  17  232  570  1151   88   7   10  34   88
# 6   764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7   713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8   644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9   748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 12  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# ...

# %%
#Standardizing the variables
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(x)

# %%
pd.DataFrame(X)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
# Now, Splitting the data into training and test dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.20)

# %%
print("X_train ",X_train.shape)
print("y_train ",y_train.shape)
print("X_test ",X_test.shape)
print("y_test ",y_test.shape)
# Out:
# X_train  (24, 13)
# y_train  (24,)
# X_test  (6, 13)
# y_test  (6,)

# %% [markdown]
# ## Model Training

# %% [markdown]
# -- -- As this is a Regression problem, we shall predict values using all the models which fall under regression... such as Linear Regression,Decision Tree Regressor,Random Forest Regressor,Lasso and Ridge..

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
LR_pred = LR.predict(X_test)
LR_pred_train = LR.predict(X_train)
pred_train = LR.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,LR_pred))
print('R2_score on training data:',r2_score(y_train,LR_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,LR_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,LR_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,LR_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,LR_pred)))
# Out:
# R2_score on testing data: 0.8018501074237087
# R2_score on training data: 0.8918314556179736
# Mean Absolute Error: 3.1954659688206255
# Mean Squared Error on training data: 10.825680690956034
# Mean Squared Error on testing data: 24.020170311192654
# Root Mean Squared Error: 4.901037676981544

# %% [markdown]
# -- Conclusion:
#
# 1) MAE,MSE and RMSE - These three methods measures the errors by calculating the difference between the predicted values and the actual value..so the lesser the better..and in this above case of Linear Regression model we see that there are two instances..i.e MSE on training and testing data..10.82 and 24.02, which is quite a difference(the lesser the difference the better)..
#
# 2) r2 score - (coefficient of determination- ranges from 0 to 1)..in this case..R squared value on testing data is 0.8018 which explains 80.18% of variation in target variable, which is a very good rate...

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=LR_pred,y=y_test)
plt.plot(LR_pred,LR_pred,color = 'b')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# #### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)
dtr_pred = dtr.predict(X_test)
dtr_pred_train = dtr.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,dtr_pred))
print('R2_score on training data:',r2_score(y_train,dtr_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,dtr_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,dtr_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,dtr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dtr_pred)))
# Out:
# R2_score on testing data: -0.5178735105407881
# R2_score on training data: 1.0
# Mean Absolute Error: 12.0
# Mean Squared Error on training data: 0.0
# Mean Squared Error on testing data: 184.0
# Root Mean Squared Error: 13.564659966250536

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=dtr_pred,y=y_test)
plt.plot(dtr_pred,dtr_pred,color = 'b')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Decision Tree Regressor')
plt.show()

# %% [markdown]
# #### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
rfr_pred = rfr.predict(X_test)
rfr_pred_train = rfr.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,rfr_pred))
print('R2_score on training data:',r2_score(y_train,rfr_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,rfr_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,rfr_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,rfr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rfr_pred)))
# Out:
# R2_score on testing data: 0.1483725939505044
# R2_score on training data: 0.9116595000607144
# Mean Absolute Error: 8.81
# Mean Squared Error on training data: 8.841258333333329
# Mean Squared Error on testing data: 103.23616666666663
# Root Mean Squared Error: 10.16051999981628

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=rfr_pred,y=y_test)
plt.plot(rfr_pred,rfr_pred,color = 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Random Forest Regressor')
plt.show()

# %% [markdown]
# #### Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train,y_train)
svr_pred = svr.predict(X_test)
svr_pred_train = svr.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,svr_pred))
print('R2_score on training data:',r2_score(y_train,svr_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,svr_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,svr_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
# Out:
# R2_score on testing data: -0.03648223628841918
# R2_score on training data: 0.22215123690095584
# Mean Absolute Error: 8.830755453553023
# Mean Squared Error on training data: 77.84834660828228
# Mean Squared Error on testing data: 125.64467997674059
# Root Mean Squared Error: 11.209133774593852

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=svr_pred,y=y_test)
plt.plot(svr_pred,svr_pred,color = 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Support Vector Regressor')
plt.show()

# %% [markdown]
# -- Conclusion:
#
# 1) MAE,MSE and RMSE - These three methods measures the errors by calculating the difference between the predicted values and the actual value..so the lesser the better..and in this above case of Decision Tree Regressor,Random Forest regressor and Support Vector Regressor model we see that in the two instances observed..i.e MSE on training and testing data..the MSE on training data is quite lower in all the models but their performance on the testing data is very poor as we can see from the MSE on testing data...and the difference between these three models are very huge..which is not compatible for our prediction of values.
#
#
# 2) r2 score - (coefficient of determination- ranges from 0 to 1)..in this case..R squared value on testing data is very poor when compared to their scores of training data..and therefore we shall not be choosing these above mentioned models..as it performes very bad for our prediction of values..

# %% [markdown]
# #### Lasso and Ridge Model

# %%
#Regularization techniques
from sklearn.linear_model import Lasso,Ridge

# %%
l = Lasso(alpha=0.00001) #We can change the alpha value for regularization strength(here alpha = 0.0001 as it performs well with that value)
l.fit(X_train,y_train)
l_pred = l.predict(X_test)
l_pred_train = r.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,l_pred))
print('R2_score on training data:',r2_score(y_train,l_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,l_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,l_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,l_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,l_pred)))
# Out:
# R2_score on testing data: 0.8018430575386547
# R2_score on training data: 0.8918314556128707
# Mean Absolute Error: 3.1955104255801934
# Mean Squared Error on training data: 10.825680691466738
# Mean Squared Error on testing data: 24.021024913925302
# Root Mean Squared Error: 4.901124862103117

# %%
r = Ridge(alpha=0.00001)#We can change the alpha value for regularization strength(here alpha = 0.0001 as it performs well with that value)
r.fit(X_train,y_train)
r_pred = r.predict(X_test)
r_pred_train = r.predict(X_train)
print('R2_score on testing data:',r2_score(y_test,r_pred))
print('R2_score on training data:',r2_score(y_train,r_pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,r_pred))
print('Mean Squared Error on training data:',mean_squared_error(y_train,r_pred_train))
print('Mean Squared Error on testing data:',mean_squared_error(y_test,r_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,r_pred)))
# Out:
# R2_score on testing data: 0.8018492703751603
# R2_score on training data: 0.8918314556128707
# Mean Absolute Error: 3.195474301167186
# Mean Squared Error on training data: 10.825680691466738
# Mean Squared Error on testing data: 24.020271780077792
# Root Mean Squared Error: 4.901048028746279

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=l_pred,y=y_test)
plt.plot(l_pred,l_pred,color = 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Lasso Regressor')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=r_pred,y=y_test)
plt.plot(r_pred,r_pred,color = 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Ridge Regressor')
plt.show()

# %% [markdown]
# -- Conclusion:
#
# 1) MAE,MSE and RMSE - These three methods measures the errors by calculating the difference between the predicted values and the actual value..and in this above case of both Lasso and Ridge model we see that in the two instances..i.e MSE on training and testing data..both models having the same values 10.82 and 24.02, which has the same difference as Linear regression model..we can observe from these values that the three models perform well with both training and testing data and not only performs well with training data like the other two models.
#
# 2) r2 score - (coefficient of determination- ranges from 0 to 1)..in this case of Lasso  model..R squared value on testing data is 0.8017 which explains 80.17% of variation in target variable..and in the case of Ridge model..R squared value on testing data is 0.8018 which explains 80.18% of variation in target variable..we can see that the Ridge regression..performs slightly better than Lasso regression..

# %% [markdown]
# ### Cross-Validation Score

# %%
#Checking Cross-validation scores for the top three models i.e(Linear,lasso and Ridge regression models)
#Linear regression
from sklearn.model_selection import cross_val_score
score = cross_val_score(LR,X,y,cv=5,scoring = 'r2')
print(score)
print(score.mean())
print("Difference between mean squared error and cross validation score is - ",(r2_score(y_test,LR_pred) + score.mean())*100)
# Out:
# [-0.20800351 -1.57678378  0.40938128  0.5295714   0.75194203]
# -0.018778517239299308
# Difference between mean squared error and cross validation score is -  78.30715901844093

# %%
#Lasso regression
score = cross_val_score(l,X,y,scoring = 'r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,l_pred) + score.mean())*100)
# Out:
# [-0.20779847 -1.57668552  0.40926373  0.52948834  0.75211841]
# -0.01872270182310711
# Difference between R2 score and cross validation score is -  78.30568659078146

# %%
#Ridge regression
score = cross_val_score(r,X,y,scoring = 'r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,r_pred) + score.mean())*100)
# Out:
# [-0.20796263 -1.57687351  0.40935946  0.52955295  0.75197676]
# -0.018789395987562064
# Difference between R2 score and cross validation score is -  78.3052341204785

# %% [markdown]
# -- Conclusion:
#
# From the above outputs from the cross-validation scores, we can observe that the scores from the top three models does not fluctuate much, which is a good sign to start with..For the purpose of selection of models out of these three, we can see that the model with the least difference between the r2 score and mean cross val scores is the Ridge regression model..
# Therefore, we shall be choosing Ridge regression as our final model because of it's performance with the training and as well as with the testing data as analysed above in the metrices such  as MSE,r2 score etc...as well as with the cross validation scores seen above.

# %% [markdown]
# ### HyperParameter Tuning

# %%
param = {'alpha':[0.1,0.0001,1e-04,1e-5,1e-9,1e-6,1e-25,1e-30]}
r = Ridge()

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = r,param_grid = param,cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 0.0001, 0.0001, 1e-05, 1e-09, 1e-06,
#                                    1e-25, 1e-30]})

# %%
Final_model = Ridge(alpha = 1e-25)
Final_model.fit(X_train,y_train)
fm_pred = Final_model.predict(X_test)
print('R2_score:',r2_score(y_test,fm_pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,fm_pred))
print('Mean Squared Error:',mean_squared_error(y_test,fm_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,fm_pred)))
# Out:
# R2_score: 0.8018501074237092
# Mean Absolute Error: 3.1954659688206255
# Mean Squared Error: 24.020170311192576
# Root Mean Squared Error: 4.901037676981536

# %% [markdown]
# -- By numerous trial and error, by hyper parameter tuning..we have increased the r2_score slightly.. Therefore,we can save this model as the final model..and also save this model..for prediction purposes..

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(Final_model,"Baseball_Case_Study.pkl")
# Out:
# ['Baseball_Case_Study.pkl']

# %%
model = joblib.load("Baseball_Case_Study.pkl")
prediction = model.predict(X_test)
prediction
# Out:
# array([71.83688237, 86.9068548 , 79.89899633, 79.68509924, 64.02604734,
#        84.0028238 ])

# %%
b = np.array(y_test)
df = pd.DataFrame()
df['Predicted'] = prediction
df['Original'] = b
df
# Out:
#    Predicted  Original
# 0  71.836882        68
# 1  86.906855        98
# 2  79.898996        78
# 3  79.685099        81
# 4  64.026047        64
# 5  84.002824        83

# %%
#Visually representing the actual vs predicted values..
plt.figure(figsize=(15,15))
sns.lineplot(data=df)
plt.title('Actual vs Predicted values')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted values')
